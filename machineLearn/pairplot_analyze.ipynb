# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv('./final_data/real-cluster-description_2017-2019.csv')

# %%
df1
# Out:
#        Cluster_id  Week      Time  pickup_count  Trip_Total  Trip_Miles  \
# 0               0     1  00:00:00      0.371795      11.875        1.95
# 1               0     1  01:00:00      0.192308      14.375        2.70
# 2               0     1  02:00:00      0.108974      10.250        2.12
# 3               0     1  03:00:00      0.250000      19.000        5.24
# 4               0     1  04:00:00      0.564103      29.325        8.30
# ...           ...   ...       ...           ...         ...         ...
# 20862         252     5  13:00:00      0.012821       3.250        0.08
# 20863         253     1  16:00:00      0.012821      25.250        8.58
# 20864         254     5  07:00:00      0.012821       3.250        0.05
# 20865         254     5  15:00:00      0.006410       4.250        0.50
# 20866         255     5  13:00:00      0.012821      21.125        7.43
#
#        Profits_m  Profits_s        mph   Tips_yn   long_yn  traffic_yn  \
# ...

# %%
plt.figure(figsize=(16,16))
sns.heatmap(df1.corr(), annot=True,
            vmin=0, vmax=1, linewidths=0.1,
           square=True, cmap='YlGnBu', linecolor='black')
plt.title('Taxi_feature')
#plt.savefig('Taxi-feature')
# Out:
# Text(0.5, 1.0, 'Taxi_feature')

# %%
df1[['Tips_yn']].describe()

# %%
df1['Profits_mProfits_m_level'].describe()
# Out:
# count    20867.000000
# mean         7.087851
# std         33.515856
# min          1.801802
# 25%          3.333333
# 50%          3.956225
# 75%          5.032155
# max       3410.681818
# Name: Profits_m, dtype: float64

# %%
def totallevel(x):
    if x <= 0.01519:
        return 'low'
    elif x > 0.01519 and x <= 0.02462:
        return 'average'
    else:
        return 'High'

# %%
df1['Profits_s_level']=df1['Profits_s'].apply(lambda x:totallevel(x))

# %%
df = df1[['Profits_s_level','Trip_Total','pickup_count','mph','Tips_yn','long_yn','traffic_yn']]

# %%
import seaborn as sns
fig = sns.pairplot(df.sort_values(by='Profits_s_level', ascending=False), 
                   hue='Profits_s_level', size=2.5);
fig
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
fig.savefig('Profits_m_.png')

# %%
l = df1[df1['Trip_Miles']>16]

# %%
l[['']]
